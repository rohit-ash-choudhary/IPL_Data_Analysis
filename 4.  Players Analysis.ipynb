# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
players=pd.read_excel("C:\\Users\\Ashhh Choudhary\\Downloads\\Player.xlsx")
players
# Out:
#               Player_Name        DOB Batting_Hand           Bowling_Skill  \
# 0          A Ashish Reddy 1991-02-24   Right_Hand        Right-arm medium
# 1              A Chandila 1983-12-05   Right_Hand      Right-arm offbreak
# 2                A Chopra 1977-09-19   Right_Hand      Right-arm offbreak
# 3             A Choudhary        NaT   Right_hand    Left-arm fast-medium
# 4             A Dananjaya        NaT   Right_Hand      Right-arm offbreak
# 5              A Flintoff 1977-12-06   Right_Hand   Right-arm fast-medium
# 6                 A Hales        NaT   Right_hand                     NaN
# 7                A Joseph        NaT   Right_Hand          Right-arm fast
# 8                A Kumble 1970-10-17   Right_Hand         Legbreak googly
# 9                A Mishra 1982-11-24   Right_Hand                Legbreak
# 10               A Mithun 1989-10-25   Right_Hand        Right-arm medium
# 11               A Mukund 1990-01-06   Right_Hand         Legbreak googly
# ...

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
players.shape
# Out:
# (566, 5)

# %%
players.isnull().sum()
# Out:
# Player_Name       0
# DOB              95
# Batting_Hand      3
# Bowling_Skill    64
# Country          95
# dtype: int64

# %%
players["Batting_Hand"].value_counts()
# Out:
# Right_Hand    373
# Left_Hand     142
# Right_hand     48
# Name: Batting_Hand, dtype: int64

# %% [markdown]
# # Batting Hand Chart

# %%
plt.figure(figsize=(10,10))
plt.pie(players["Batting_Hand"].value_counts().values,labels=players["Batting_Hand"].value_counts().keys(),autopct="%0.03f%%",explode=[0.0,0.0,0.2])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a330a679d0>,
# ...
#  [Text(-0.5375502904805162, 0.9597081250069278, 'Right_Hand'),
#   Text(0.2643931262761933, -1.0677529090467988, 'Left_Hand'),
#   Text(1.2536466592078166, -0.3440494933248422, 'Right_hand')],
#  [Text(-0.2932092493530088, 0.5234771590946878, '66.252%'),
#   Text(0.14421443251428726, -0.5824106776618901, '25.222%'),
#   Text(0.7714748672048102, -0.2117227651229798, '8.526%')])

# %% [markdown]
# # Bowling_Skill

# %%
players["Bowling_Skill"].value_counts()
# Out:
# Right-arm medium          107
# Right-arm offbreak         91
# Right-arm fast-medium      68
# Slow left-arm orthodox     50
# Right-arm fast             39
# Right-arm medium-fast      38
# Legbreak                   30
# Legbreak googly            28
# Left-arm fast-medium       19
# Left-arm medium            11
# Left-arm medium-fast        9
# Slow left-arm chinaman      5
# Left-arm fast               4
# Right-arm Fast              1
# Right-arm bowler            1
# Right-arm Medium            1
# Name: Bowling_Skill, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.pie(players["Bowling_Skill"].value_counts().values,labels=players["Bowling_Skill"].value_counts().keys(),autopct="%0.03f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1a330bd3220>,
# ...
#  [Text(0.8624617320897764, 0.682758933065473, 'Right-arm medium'),
#   Text(-0.364699056361011, 1.0377835026099558, 'Right-arm offbreak'),
#   Text(-1.0690419088722145, 0.2591320070443859, 'Right-arm fast-medium'),
#   Text(-0.9649965977144815, -0.5279976954490192, 'Slow left-arm orthodox'),
#   Text(-0.5400339912969562, -0.9583127298767764, 'Right-arm fast'),
#   Text(-0.03441406990955389, -1.099461537204581, 'Right-arm medium-fast'),
#   Text(0.4225414035964434, -1.0156075828028992, 'Legbreak'),
#   Text(0.7556074173301066, -0.7994106772340024, 'Legbreak googly'),
#   Text(0.9549143963710178, -0.5460205999807836, 'Left-arm fast-medium'),
#   Text(1.0400455919472658, -0.35819710589431314, 'Left-arm medium'),
#   Text(1.0766257323150965, -0.2255593769209833, 'Left-arm medium-fast'),
#   Text(1.0922330749027345, -0.13048720277681494, 'Slow left-arm chinaman'),
#   Text(1.097846669544922, -0.06879455043186723, 'Left-arm fast'),
# ...

# %% [markdown]
# # Country Wise Player

# %%
players["Country"].value_counts()
# Out:
# India           264
# Australia        72
# South Africa     39
# New Zealand      22
# Sri Lanka        20
# West Indies      19
# England          14
# Pakistan         13
# Bangladesh        5
# Zimbabwea         2
# Netherlands       1
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(players["Country"].value_counts().keys(),players["Country"].value_counts().values,width=.3)
# Out:
# <BarContainer object of 11 artists>

# %%
plt.figure(figsize=(20,20))
plt.pie(players["Country"].value_counts().values,labels=players["Country"].value_counts().keys(),autopct="%0.03f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1a3302697c0>,
# ...
#  [Text(-0.20784891199504588, 1.0801846276366258, 'India'),
#   Text(-0.7173174652234344, -0.833939838408879, 'Australia'),
#   Text(0.03301185846553083, -1.0995045325966837, 'South Africa'),
#   Text(0.4654342204537462, -0.9966799819553986, 'New Zealand'),
#   Text(0.72286398666088, -0.829136693669228, 'Sri Lanka'),
#   Text(0.9118045865060566, -0.6153148755121393, 'West Indies'),
#   Text(1.0241525009786134, -0.40138716314706874, 'England'),
#   Text(1.079485460066797, -0.2114500922307105, 'Pakistan'),
#   Text(1.0970405541621218, -0.0806351196667113, 'Bangladesh'),
#   Text(1.0996085171487773, -0.029344659034779976, 'Zimbabwea'),
#   Text(1.099975531323315, -0.007336926467596929, 'Netherlands')],
#  [Text(-0.11337213381547956, 0.5891916150745231, '56.051%'),
#   Text(-0.3912640719400551, -0.4548762754957521, '15.287%'),
#   Text(0.018006468253925902, -0.5997297450527365, '8.280%'),
# ...
