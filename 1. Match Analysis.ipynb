# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


#plt.rcParams['figure.figsize']=17,8

# %%
ipl_match=pd.read_csv("C:\\Users\\Ashhh Choudhary\\Downloads\\archive (1)\\matches.csv")
ipl_match
# Out:
#         id    Season            city        date                        team1  \
# 0        1  IPL-2017       Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017            Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017          Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017          Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017       Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        6  IPL-2017       Hyderabad  09-04-2017                Gujarat Lions
# 6        7  IPL-2017          Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017          Indore  10-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017            Pune  11-04-2017             Delhi Daredevils
# 9       10  IPL-2017          Mumbai  12-04-2017          Sunrisers Hyderabad
# 10      11  IPL-2017         Kolkata  13-04-2017              Kings XI Punjab
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
ipl_match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_match.shape
# Out:
# (756, 18)

# %%
empty_value_in_columns=ipl_match.isnull().sum()/ipl_match.shape[0]*100
empty_value_in_columns
# Out:
# id                  0.000000
# Season              0.000000
# city                0.925926
# date                0.000000
# team1               0.000000
# team2               0.000000
# toss_winner         0.000000
# toss_decision       0.000000
# result              0.000000
# dl_applied          0.000000
# winner              0.529101
# win_by_runs         0.000000
# win_by_wickets      0.000000
# player_of_match     0.529101
# venue               0.000000
# umpire1             0.264550
# umpire2             0.264550
# umpire3            84.259259
# dtype: float64

# %%
more_then_20percentage_value_empty=empty_value_in_columns[empty_value_in_columns>20].keys()
more_then_20percentage_value_empty
# Out:
# Index(['umpire3'], dtype='object')

# %%
ipl_match.drop(columns=['umpire3'],inplace=True)

# %%
ipl_match.shape
# Out:
# (756, 17)

# %%
ipl_match["player_of_match"].value_counts()
# Out:
# CH Gayle             21
# AB de Villiers       20
# MS Dhoni             17
# DA Warner            17
# RG Sharma            17
# YK Pathan            16
# SR Watson            15
# SK Raina             14
# G Gambhir            13
# V Kohli              12
# MEK Hussey           12
# AM Rahane            12
# AD Russell           11
# DR Smith             11
# A Mishra             11
# V Sehwag             11
# KA Pollard           10
# JH Kallis            10
# AT Rayudu             9
# SP Narine             9
# SE Marsh              9
# SR Tendulkar          8
# Harbhajan Singh       8
# UT Yadav              8
# RA Jadeja             8
# RV Uthappa            7
# AC Gilchrist          7
# Rashid Khan           7
# BJ Hodge              6
# HH Pandya             6
# SL Malinga            6
# M Vijay               6
# RR Pant               6
# S Dhawan              6
# A Nehra               6
# JD Unadkat            5
# SV Samson             5
# JC Buttler            5
# ...

# %%
top5player=ipl_match["player_of_match"].value_counts()[0:10]
top5player.values
# Out:
# array([21, 20, 17, 17, 17], dtype=int64)

# %%
top5_max_manofthematch_name=ipl_match["player_of_match"].value_counts()[0:10].keys()
top5_max_manofthematch_name
# Out:
# Index(['CH Gayle', 'AB de Villiers', 'MS Dhoni', 'DA Warner', 'RG Sharma',
#        'YK Pathan', 'SR Watson', 'SK Raina', 'G Gambhir', 'V Kohli'],
#       dtype='object')

# %%
top5_maxtop5_max_manofthematch_times=ipl_match["player_of_match"].value_counts()[0:10].values
top5_maxtop5_max_manofthematch_times
# Out:
# array([21, 20, 17, 17, 17, 16, 15, 14, 13, 12], dtype=int64)

# %% [markdown]
# # man of the match

# %% [markdown]
# Top 10 man of the match players

# %%
plt.figure(figsize=(15,9))
plt.bar(top5_max_manofthematch_name,top5_maxtop5_max_manofthematch_times,color="yellow",label="Top 10 man of the match player")
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Top 15 Number of man of match players

# %%
Man_of_match=ipl_match["player_of_match"].value_counts()[0:5]
player_name=ipl_match["player_of_match"].value_counts().keys()[0:15]
how_many_times_manofmatch=ipl_match["player_of_match"].value_counts().values[0:15]
player_name
how_many_times_manofmatch
# Out:
# array([21, 20, 17, 17, 17, 16, 15, 14, 13, 12, 12, 12, 11, 11, 11],
#       dtype=int64)

# %%
plt.figure(figsize=(15,15))
plt.pie(how_many_times_manofmatch,labels=player_name)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4e50b1b80>,
# ...
#  [Text(1.0504634310733425, 0.32638409884309827, 'CH Gayle'),
#   Text(0.6928654071136704, 0.8543638145574799, 'AB de Villiers'),
#   Text(0.1650609242307148, 1.0875453513725772, 'MS Dhoni'),
#   Text(-0.36383888138491116, 1.0380853858872, 'DA Warner'),
#   Text(-0.8078886656493105, 0.7465359361178648, 'RG Sharma'),
#   Text(-1.0593939202932279, 0.2961157234017575, 'YK Pathan'),
#   Text(-1.0837421132629834, -0.1884224825764777, 'SR Watson'),
#   Text(-0.915164109830324, -0.6103070146069688, 'SK Raina'),
#   Text(-0.616855295822811, -0.910763165710687, 'G Gambhir'),
#   Text(-0.2579404890974552, -1.0693300258031502, 'V Kohli'),
#   Text(0.11811951885164504, -1.093639693530852, 'MEK Hussey'),
#   Text(0.48031638656466585, -0.9895939413706324, 'AM Rahane'),
#   Text(0.7750230018594265, -0.7806019130061131, 'AD Russell'),
#   Text(0.9790303417161397, -0.5014973479483007, 'DR Smith'),
# ...

# %%
ipl_match['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(ipl_match['result'].value_counts().keys(),ipl_match['result'].value_counts().values)
# Out:
# <BarContainer object of 3 artists>

# %%
ipl_match["toss_winner"].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %% [markdown]
# tosser winner team

# %%
plt.figure(figsize=(50,10))
sns.lineplot(ipl_match["toss_winner"].value_counts().keys(),ipl_match["toss_winner"].value_counts().values)
# Out:
# C:\Users\Ashhh Choudhary\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
batting_first=ipl_match[ipl_match['win_by_runs']!=0]
batting_first
# Out:
#         id    Season            city        date                        team1  \
# 0        1  IPL-2017       Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017       Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017            Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017         Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017           Delhi  15-04-2017             Delhi Daredevils
# 16      17  IPL-2017       Bangalore  16-04-2017       Rising Pune Supergiant
# 18      19  IPL-2017       Hyderabad  17-04-2017          Sunrisers Hyderabad
# 19      20  IPL-2017          Rajkot  18-04-2017  Royal Challengers Bangalore
# 20      21  IPL-2017       Hyderabad  19-04-2017          Sunrisers Hyderabad
# 23      24  IPL-2017          Mumbai  22-04-2017               Mumbai Indians
# 25      26  IPL-2017          Rajkot  23-04-2017              Kings XI Punjab
# ...

# %%
batting_first.head()
# Out:
#     id    Season       city        date                        team1  \
# 0    1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4    5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13  14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14  15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.figure(figsize=(15,10))
plt.hist(batting_first['win_by_runs'],bins=7,rwidth=0.8,color='y')
plt.title("Distrubtion By Runs")
plt.xlabel("Runs")
plt.show()

# %%
batting_first['winner'].value_counts()

# %% [markdown]
# Top 4 Batting First Winner Team

# %%
plt.figure(figsize=(10,10))
plt.bar(batting_first['winner'].value_counts().keys()[0:4],batting_first['winner'].value_counts().values[0:4],color=['r','g','y','b'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(10,10))
plt.pie(batting_first['winner'].value_counts(),labels=batting_first['winner'].value_counts().keys(),autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4e6665ee0>,
# ...
#  [Text(0.9483265621806172, 0.5573838277728304, 'Mumbai Indians'),
#   Text(0.02563386044208945, 1.0997012799841763, 'Chennai Super Kings'),
#   Text(-0.8010226010255528, 0.7538983967659425, 'Kings XI Punjab'),
#   Text(-1.0976587644223588, 0.07173030661290015, 'Kolkata Knight Riders'),
#   Text(-0.9099615286095598, -0.6180372290166294, 'Royal Challengers Bangalore'),
#   Text(-0.3959592959126898, -1.0262632391254825, 'Sunrisers Hyderabad'),
#   Text(0.1786580387418249, -1.08539453895481, 'Rajasthan Royals'),
#   Text(0.6638604303770628, -0.8770914028649359, 'Delhi Daredevils'),
#   Text(0.9534813337914305, -0.5485192303933517, 'Deccan Chargers'),
#   Text(1.0514175368316108, -0.32329732947079654, 'Pune Warriors'),
#   Text(1.0789886618399935, -0.21397071673651988, 'Rising Pune Supergiant'),
#   Text(1.0919321532371848, -0.1329818511181329, 'Delhi Capitals'),
#   Text(1.0969423967462106, -0.08195961335120551, 'Kochi Tuskers Kerala'),
# ...

# %% [markdown]
# Batting First

# %%
Bowling_First_Winner_Team=ipl_match[ipl_match["win_by_wickets"]!=0]
Bowling_First_Winner_Team
# Out:
#         id    Season            city        date                        team1  \
# 1        2  IPL-2017            Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017          Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017          Indore  08-04-2017       Rising Pune Supergiant
# 5        6  IPL-2017       Hyderabad  09-04-2017                Gujarat Lions
# 6        7  IPL-2017          Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017          Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017          Mumbai  12-04-2017          Sunrisers Hyderabad
# 10      11  IPL-2017         Kolkata  13-04-2017              Kings XI Punjab
# 11      12  IPL-2017       Bangalore  14-04-2017  Royal Challengers Bangalore
# 12      13  IPL-2017          Rajkot  14-04-2017       Rising Pune Supergiant
# 15      16  IPL-2017          Mumbai  16-04-2017                Gujarat Lions
# ...

# %%
Bowling_First_Winner_Team.head()
# Out:
#    id    Season       city        date                   team1  \
# 1   2  IPL-2017       Pune  06-04-2017          Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017           Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017  Rising Pune Supergiant
# 5   6  IPL-2017  Hyderabad  09-04-2017           Gujarat Lions
# 6   7  IPL-2017     Mumbai  09-04-2017   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
Bowling_First_Winner_Team['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Delhi Daredevils               42
# Kings XI Punjab                42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(35,10))
plt.xlabel("Team Name",fontsize=15,color='r')
plt.ylabel("No of Match Win",fontsize=15,color='r')
plt.title("Match Win by TEAMS",color='y',fontsize=25)
sns.lineplot(Bowling_First_Winner_Team['winner'].value_counts().keys(),Bowling_First_Winner_Team['winner'].value_counts().values)
# Out:
# C:\Users\Ashhh Choudhary\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Match Win by TEAMS'}, xlabel='Team Name', ylabel='No of Match Win'>

# %% [markdown]
# Top 5 Bowling First Winner Team

# %%
plt.figure(figsize=(20,10))
plt.bar(Bowling_First_Winner_Team['winner'].value_counts().keys()[0:5],Bowling_First_Winner_Team['winner'].value_counts().values[0:5],color=['r','g','b','y','r'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,10))
plt.title("Tem Win By Wicket",color="b")
plt.xlabel("No of Wicket",color="y")
plt.ylabel("No of Matches",color="y")
plt.hist(Bowling_First_Winner_Team['win_by_wickets'],rwidth=.8,bins=10)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(Bowling_First_Winner_Team['winner'].value_counts(),labels=Bowling_First_Winner_Team['winner'].value_counts().keys(),autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4eef4fcd0>,
# ...
#  [Text(0.9983329623836416, 0.4618780101047276, 'Kolkata Knight Riders'),
#   Text(0.34315510477407346, 1.0451050540818827, 'Mumbai Indians'),
#   Text(-0.469589129872304, 0.994729133536247, 'Royal Challengers Bangalore'),
#   Text(-1.0186933326018242, 0.415046857731256, 'Chennai Super Kings'),
#   Text(-1.0368582653410094, -0.3673213002182603, 'Rajasthan Royals'),
#   Text(-0.5743854605141011, -0.9381265067942618, 'Delhi Daredevils'),
#   Text(0.1104657133114124, -1.094439274780744, 'Kings XI Punjab'),
#   Text(0.6520603064504145, -0.8858991797895467, 'Sunrisers Hyderabad'),
#   Text(0.8858992637336905, -0.6520601924025918, 'Gujarat Lions'),
#   Text(0.987343061874614, -0.48492646676384094, 'Deccan Chargers'),
#   Text(1.0424185113345334, -0.3512316147887253, 'Pune Warriors'),
#   Text(1.0704946012627996, -0.2530638430657369, 'Delhi Capitals'),
#   Text(1.0881331687620566, -0.16114033337388253, 'Rising Pune Supergiant'),
# ...

# %% [markdown]
# # Overall Winner Top 5 Team of IPL

# %%
ipl_match["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
top_three_team_overall_winner_ipl=ipl_match["winner"].value_counts()[0:3]
top_three_team_overall_winner_ipl
# Out:
# Mumbai Indians           109
# Chennai Super Kings      100
# Kolkata Knight Riders     92
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.title("Top 3 Team Which Win Maximum Overall in all Seasons")
plt.xlabel("Team Name")
plt.ylabel("Number of Match")
plt.bar(top_three_team_overall_winner_ipl.keys(),top_three_team_overall_winner_ipl.values,color=['r','b','y'],width=.15)
# Out:
# <BarContainer object of 3 artists>

# %%
Seasons=ipl_match["Season"].value_counts().keys()
Number_of_Match=ipl_match["Season"].value_counts().values
print(Seasons)
print(Number_of_Match)
ss={"Season":['IPL-2013', 'IPL-2012', 'IPL-2011', 'IPL-2010', 'IPL-2018', 'IPL-2019',
       'IPL-2016', 'IPL-2014', 'IPL-2017', 'IPL-2015', 'IPL-2008', 'IPL-2009'],
    
    'Number Of Match':[76, 74, 73, 60, 60, 60, 60, 60,59,59, 58, 57]
}
# Out:
# Index(['IPL-2013', 'IPL-2012', 'IPL-2011', 'IPL-2010', 'IPL-2018', 'IPL-2019',
#        'IPL-2016', 'IPL-2014', 'IPL-2017', 'IPL-2015', 'IPL-2008', 'IPL-2009'],
#       dtype='object')
# [76 74 73 60 60 60 60 60 59 59 58 57]

# %%
Season_by_match=pd.DataFrame(ss,columns=["Season","Number Of Match"])
Season_by_match
# Out:
#       Season  Number Of Match
# 0   IPL-2013               76
# 1   IPL-2012               74
# 2   IPL-2011               73
# 3   IPL-2010               60
# 4   IPL-2018               60
# 5   IPL-2019               60
# 6   IPL-2016               60
# 7   IPL-2014               60
# 8   IPL-2017               59
# 9   IPL-2015               59
# 10  IPL-2008               58
# 11  IPL-2009               57

# %%
city_wise_match=ipl_match["city"].value_counts()
city_wise_match
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Ahmedabad          12
# Centurion          12
# Rajkot             10
# Mohali             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Abu Dhabi           7
# Cape Town           7
# Port Elizabeth      7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %% [markdown]
# How Much Percentage Team Win toss Also Win Match

# %%
percentage_match_win_that_toss_win=(np.sum(ipl_match["winner"]==ipl_match["toss_winner"]))/ipl_match.shape[0]*100
percentage_match_win_that_toss_win
# Out:
# 51.98412698412699

# %% [markdown]
# 51.98412698412699 % Team win toss also win match
